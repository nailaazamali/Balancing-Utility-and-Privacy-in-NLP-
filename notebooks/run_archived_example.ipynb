# %% [markdown]
# # Archived runnable example
#
# This notebook runs the separate archived cohort included with the repository. It is useful for checking the pipeline, but it is not the exact data split used for the paper.

# %%
from pathlib import Path
ROOT = Path.cwd()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
print(ROOT)

# %%
# %pip install -q -r {ROOT / 'requirements.txt'}
# !python -m spacy download en_core_web_sm -q

# %%
# !cd {ROOT} && python scripts/validate_repository.py

# %%
# !cd {ROOT} && python experiments/run_main.py --config configs/archived_run.json --device cpu --output-dir outputs/main
